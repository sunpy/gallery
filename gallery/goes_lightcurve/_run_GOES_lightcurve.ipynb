# %% [markdown]
# # Working with GOES LightCurves

# %% [markdown]
# ## Overview

# %% [markdown]
# A basic example working with GOES light curves in SunPy. Below, we generate a lightcurve for the previous day and create a simple plot.

# %%
# %matplotlib inline

from sunpy.lightcurve import GOESLightCurve
goes = GOESLightCurve.from_yesterday()
fig = goes.peek()
# Out:
# /Users/ainglis/python/sunpy/sunpy/__init__.py:21: Warning: Missing version.py; you need to run setup.py
#   warnings.warn('Missing version.py; you need to run setup.py', Warning)
# /Users/ainglis/python/sunpy/sunpy/lightcurve/lightcurve.py:253: RuntimeWarning: Using existing file rather than downloading, use overwrite=True to override.
#   warnings.warn("Using existing file rather than downloading, use overwrite=True to override.", RuntimeWarning)
# /Users/ainglis/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:371: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# To see what time-range the data is for, we can use the `time_range` method.

# %%
goes.time_range()
# Out:
#     Start: 2014/07/19 23:59:59
#     End:   2014/07/20 23:59:55
#     Center:2014/07/20 11:59:57
#     Duration:0 days or
#            1439.93895 minutes or
#            86396.337 seconds

# %% [markdown]
# The underlying data is stored as a [pandas DataFrame](http://pandas.pydata.org/pandas-docs/dev/dsintro.html) object.

# %%
goes.data
# Out:
#                                     xrsa  xrsb
# 2014-07-19 23:59:59.571999  1.000000e-09     0
# 2014-07-20 00:00:01.618999  1.000000e-09     0
# 2014-07-20 00:00:03.668999  1.000000e-09     0
# 2014-07-20 00:00:05.714999  1.000000e-09     0
# 2014-07-20 00:00:07.764999  1.000000e-09     0
# 2014-07-20 00:00:09.811999  1.000000e-09     0
# 2014-07-20 00:00:11.858999  1.000000e-09     0
# 2014-07-20 00:00:13.908999  1.000000e-09     0
# 2014-07-20 00:00:15.954999  1.000000e-09     0
# 2014-07-20 00:00:18.004999  1.000000e-09     0
# 2014-07-20 00:00:20.051999  1.000000e-09     0
# 2014-07-20 00:00:22.098999  1.000000e-09     0
# 2014-07-20 00:00:24.148999  1.000000e-09     0
# 2014-07-20 00:00:26.194999  1.000000e-09     0
# 2014-07-20 00:00:28.244999  1.000000e-09     0
# 2014-07-20 00:00:30.291999  1.000000e-09     0
# 2014-07-20 00:00:32.338999  1.000000e-09     0
# 2014-07-20 00:00:34.388999  1.000000e-09     0
# 2014-07-20 00:00:36.434999  1.000000e-09     0
